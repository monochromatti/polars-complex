# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import polars as pl
import polars_complex
from polars import col
from polars_complex import ccol

# %%
test_data = pl.DataFrame(
    {
        "a": np.random.rand(10),
        "b": np.random.rand(10),
        "c": np.random.rand(10),
        "d": np.random.rand(10),
    }
).select(
    ccol("a", "b") / col("b").complex.into(),
)
test_data
# Out:
# shape: (10, 1)
# ┌─────────────────┐
# │ real            │
# │ ---             │
# │ struct[2]       │
# ╞═════════════════╡
# │ {1.158601,1.0}  │
# │ {1.111038,1.0}  │
# │ {2.14535,1.0}   │
# │ {0.38892,1.0}   │
# │ {1.959047,1.0}  │
# │ {1.129409,1.0}  │
# │ {0.617182,1.0}  │
# │ {1.406333,1.0}  │
# │ {26.562663,1.0} │
# │ {0.158275,1.0}  │
# └─────────────────┘
